# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes = True)
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.impute import SimpleImputer

from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('instacart_final.csv')
df.head()
# Out:
#    Unnamed: 0  order_id  product_id  add_to_cart_order  reordered  user_id  \
# 0           0         2       33120                  1          1   202279
# 1           1        26       33120                  5          0   153404
# 2           2       120       33120                 13          0    23750
# 3           3       327       33120                  5          1    58707
# 4           4       390       33120                 28          1   166654
#
#   eval_set  order_number  order_dow  order_hour_of_day  \
# 0    prior             3          5                  9
# 1    prior             2          0                 16
# 2    prior            11          6                  8
# 3    prior            21          6                  9
# 4    prior            48          0                 12
#
#    days_since_prior_order        product_name  aisle_id  department_id aisle  \
# 0                     8.0  Organic Egg Whites        86             16  eggs
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# order_id                        0
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# user_id                         0
# eval_set                        0
# order_number                    0
# order_dow                       0
# order_hour_of_day               0
# days_since_prior_order    2078068
# product_name                    0
# aisle_id                        0
# department_id                   0
# aisle                           0
# department                      0
# dtype: int64

# %% [raw]
# We have null values only in the days_since_prior_order column which corresponds to the first orders of each user

# %%
df = df.set_index(['user_id', 'order_number', 'add_to_cart_order'])

# %%
df = df.sort_index()

# %%
df.head(100)
# Out:
#                                         Unnamed: 0  order_id  product_id  \
# user_id order_number add_to_cart_order
# 1       1            1                    25615188   2539329         196
#                      2                     2332125   2539329       14084
#                      3                    22296199   2539329       12427
#                      4                    22274671   2539329       26088
#                      5                    27776034   2539329       26405
# ...                                            ...       ...         ...
# 2       4            2                    22322943    738281       32792
#                      3                    26771265    738281       32139
#                      4                    23833855    738281       34688
#                      5                    27326604    738281       36735
#                      6                    13280999    738281       37646
#
# ...

# %%
sample_df = df.groupby('user_id').sample(n = 50000,random_state=1,rep)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-df83e0e045cb> in <module>
# ----> 1 sample_df = df.groupby('user_id').sample(n = 50000,random_state=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in sample(self, n, frac, replace, weights, random_state)
#    3029             random_state = com.random_state(random_state)
#    3030
# -> 3031         samples = [
#    3032             obj.sample(
#    3033                 n=n, frac=frac, replace=replace, weights=w, random_state=random_state
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <listcomp>(.0)
#    3030
#    3031         samples = [
# -> 3032             obj.sample(
#    3033                 n=n, frac=frac, replace=replace, weights=w, random_state=random_state
#    3034             )
#
# ...

# %%
sample_df.shape
